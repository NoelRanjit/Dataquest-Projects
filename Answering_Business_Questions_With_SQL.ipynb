# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# 'Connected: None@chinook.db'

# %% [markdown]
# # Overview

# %% [markdown]
# For this project, we are using a trimmed version of the <a href = "https://github.com/lerocha/chinook-database">Chinook</a> database to answer a few business questions using SQL about the media store.
#
# Here's the schema diagram of the database

# %% [markdown]
# ![Chinook schema diagram](https://s3.amazonaws.com/dq-content/189/chinook-schema.svg)

# %% [markdown]
# # Tracks sold in USA

# %%
# %%sql
#
# -- Tracks sold by each genre and their percentage
#
# SELECT
#     c.country,
#     g.name,
#     COUNT(t.track_id) tracks_sold,
#
#     (CAST(COUNT(t.track_id) AS FLOAT) *100)/
#     (SELECT
#         COUNT(t.track_id) tracks_sold
#     FROM track t
#     INNER JOIN genre g ON g.genre_id = t.genre_id
#     INNER JOIN invoice_line il ON il.track_id = t.track_id
#     INNER JOIN invoice i ON i.invoice_id = il.invoice_id
#     INNER JOIN customer c ON c.customer_id = i.customer_id
#
#     WHERE country = "USA")
#     percentage
#
# FROM track t
# INNER JOIN genre g ON g.genre_id = t.genre_id
# INNER JOIN invoice_line il ON il.track_id = t.track_id
# INNER JOIN invoice i ON i.invoice_id = il.invoice_id
# INNER JOIN customer c ON c.customer_id = i.customer_id
#
# WHERE country = "USA"
#
# GROUP BY 2
# ORDER BY 3 DESC;
# Out:
# Done.
# [('USA', 'Rock', 561, 53.37773549000951),
#  ('USA', 'Alternative & Punk', 130, 12.369172216936251),
#  ('USA', 'Metal', 124, 11.798287345385347),
#  ('USA', 'R&B/Soul', 53, 5.042816365366318),
#  ('USA', 'Blues', 36, 3.4253092293054235),
#  ('USA', 'Alternative', 35, 3.330161750713606),
#  ('USA', 'Latin', 22, 2.093244529019981),
#  ('USA', 'Pop', 22, 2.093244529019981),
#  ('USA', 'Hip Hop/Rap', 20, 1.9029495718363463),
#  ('USA', 'Jazz', 14, 1.3320647002854424),
#  ('USA', 'Easy Listening', 13, 1.236917221693625),
#  ('USA', 'Reggae', 6, 0.570884871550904),
#  ('USA', 'Electronica/Dance', 5, 0.47573739295908657),
#  ('USA', 'Classical', 4, 0.38058991436726924),
#  ('USA', 'Heavy Metal', 3, 0.285442435775452),
#  ('USA', 'Soundtrack', 2, 0.19029495718363462),
#  ('USA', 'TV Shows', 1, 0.09514747859181731)]

# %%
# %%sql
#
# --  Popularity of artists by genre
#
# SELECT al.title album, ar.name artist,g.name, COUNT(t.track_id) tracks_purchased
# FROM invoice_line il
# INNER JOIN track t ON t.track_id = il.track_id
# INNER JOIN album al ON al.album_id = t.album_id
# INNER JOIN artist ar ON ar.artist_id = al.artist_id
# INNER JOIN genre g ON g.genre_id = t.genre_id
# GROUP BY 1
# ORDER BY 4 DESC
# limit 100;
# Out:
# Done.
# [('Are You Experienced?', 'Jimi Hendrix', 'Rock', 187),
#  ('Faceless', 'Godsmack', 'Metal', 96),
#  ('Mezmerize', 'System Of A Down', 'Metal', 93),
#  ('Get Born', 'JET', 'Alternative & Punk', 90),
#  ('The Doors', 'The Doors', 'Rock', 83),
#  ('Big Ones', 'Aerosmith', 'Rock', 80),
#  ('Greatest Hits I', 'Queen', 'Rock', 80),
#  ('The Police Greatest Hits', 'The Police', 'Rock', 80),
#  ('From The Muddy Banks Of The Wishkah [live]', 'Nirvana', 'Rock', 78),
#  ('My Generation - The Very Best Of The Who', 'The Who', 'Rock', 76),
#  ('Jagged Little Pill', 'Alanis Morissette', 'Rock', 75),
#  ('20th Century Masters - The Millennium Collection: The Best of Scorpions', 'Scorpions', 'Rock', 74),
#  ('For Those About To Rock We Salute You', 'AC/DC', 'Rock', 74),
#  ('My Way: The Best Of Frank Sinatra [Disc 1]', 'Frank Sinatra', 'Easy Listening', 74),
#  ('The Singles', 'The Clash', 'Alternative & Punk', 72),
#  ('Dark Side Of The Moon', 'Pink Floyd', 'Rock', 68),
#  ('News Of The World', 'Queen', 'Rock', 64),
#  ('The Cream Of Clapton', 'Eric Clapton', 'Blues', 60),
#  ('Facelift', 'Alice In Chains', 'Rock', 59),
#  ('Green', 'R.E.M.', 'Alternative & Punk', 59),
#  ('American Idiot', 'Green Day', 'Alternative & Punk', 58),
#  ('Miles Ahead', 'Miles Davis', 'Jazz', 53),
#  ('A-Sides', 'Soundgarden', 'Rock', 52),
#  ('Nevermind', 'Nirvana', 'Rock', 52),
#  ('Seek And Shall Find: More Of The Best (1963-1981)', 'Marvin Gaye', 'R&B/Soul', 51),
#  ('Use Your Illusion I', "Guns N' Roses", 'Rock', 51),
#  ('Back to Black', 'Amy Winehouse', 'R&B/Soul', 50),
#  ('Californication', 'Red Hot Chili Peppers', 'Rock', 50),
#  ('Carry On', 'Chris Cornell', 'Alternative', 50),
#  ('Let There Be Rock', 'AC/DC', 'Rock', 50),
#  ('By The Way', 'Red Hot Chili Peppers', 'Rock', 49),
#  ('Sex Machine', 'James Brown', 'R&B/Soul', 49),
#  ('Ace Of Spades', 'Motörhead', 'Metal', 48),
#  ('Greatest Hits II', 'Queen', 'Rock', 48),
#  ('Barulhinho Bom', 'Marisa Monte', 'Latin', 47),
#  ('Frank', 'Amy Winehouse', 'Pop', 47),
#  ('Hot Rocks, 1964-1971 (Disc 1)', 'The Rolling Stones', 'Rock', 47),
#  ('International Superhits', 'Green Day', 'Alternative & Punk', 47),
#  ('Voodoo Lounge', 'The Rolling Stones', 'Rock', 43),
#  ('In Your Honor [Disc 2]', 'Foo Fighters', 'Rock', 42),
#  ('Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [uk]', 'The Cult', 'Rock', 42),
#  ('Core', 'Stone Temple Pilots', 'Rock', 41),
#  ('Use Your Illusion II', "Guns N' Roses", 'Metal', 40),
#  ('Black Sabbath', 'Black Sabbath', 'Metal', 39),
#  ('Chronicle, Vol. 2', 'Creedence Clearwater Revival', 'Rock', 39),
#  ('Retrospective I (1974-1980)', 'Rush', 'Rock', 39),
#  ('Greatest Kiss', 'Kiss', 'Rock', 37),
#  ('Plays Metallica By Four Cellos', 'Apocalyptica', 'Metal', 37),
#  ('Vs.', 'Pearl Jam', 'Rock', 37),
#  ('The Colour And The Shape', 'Foo Fighters', 'Rock', 36),
#  ('Greatest Hits', 'Lenny Kravitz', 'Metal', 35),
#  ('Unplugged', 'Eric Clapton', 'Latin', 34),
#  ('Appetite for Destruction', "Guns N' Roses", 'Rock', 33),
#  ('Audioslave', 'Audioslave', 'Rock', 33),
#  ('Live On Two Legs [live]', 'Pearl Jam', 'Rock', 33),
#  ('The Best Of Van Halen, Vol. I', 'Van Halen', 'Rock', 33),
#  ('Blood Sugar Sex Magik', 'Red Hot Chili Peppers', 'Alternative & Punk', 31),
#  ('Cake: B-Sides and Rarities', 'Cake', 'Alternative', 31),
#  ('House of Pain', 'House Of Pain', 'Hip Hop/Rap', 31),
#  ('The Return Of The Space Cowboy', 'Jamiroquai', 'Electronica/Dance', 31),
#  ('Living After Midnight', 'Judas Priest', 'Metal', 30),
#  ('Riot Act', 'Pearl Jam', 'Rock', 30),
#  ('Black Sabbath Vol. 4 (Remaster)', 'Black Sabbath', 'Metal', 29),
#  ("Vault: Def Leppard's Greatest Hits", 'Def Leppard', 'Rock', 28),
#  ('Minha História', 'Os Mutantes', 'Alternative & Punk', 27),
#  ('No Security', 'The Rolling Stones', 'Rock', 27),
#  ('Unplugged [live]', 'Kiss', 'Rock', 26),
#  ('Contraband', 'Velvet Revolver', 'Rock', 25),
#  ('New Adventures In Hi-Fi', 'R.E.M.', 'Rock', 25),
#  ('One By One', 'Foo Fighters', 'Alternative & Punk', 25),
#  ('Van Halen', 'Van Halen', 'Rock', 25),
#  ('Emergency On Planet Earth', 'Jamiroquai', 'Rock', 23),
#  ('The Best Of Buddy Guy - The Millenium Collection', 'Buddy Guy', 'Blues', 23),
#  ('Diver Down', 'Van Halen', 'Rock', 21),
#  ('Master Of Puppets', 'Metallica', 'Metal', 21),
#  ('Pearl Jam', 'Pearl Jam', 'Alternative & Punk', 21),
#  ('Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro', 'O Rappa', 'Electronica/Dance', 21),
#  ('The Best Of R.E.M.: The IRS Years', 'R.E.M.', 'Alternative & Punk', 20),
#  ('UB40 The Best Of - Volume Two [uk]', 'UB40', 'Reggae', 20),
#  ('In Your Honor [Disc 1]', 'Foo Fighters', 'Rock', 18),
#  ('Jota Quest-1995', 'Jota Quest', 'Latin', 18),
#  ('St. Anger', 'Metallica', 'Metal', 18),
#  ('Warner 25 Anos', 'Antônio Carlos Jobim', 'Jazz', 18),
#  ('Misplaced Childhood', 'Marillion', 'Rock', 17),
#  ('Chronicle, Vol. 1', 'Creedence Clearwater Revival', 'Rock', 16),
#  ('Instant Karma: The Amnesty International Campaign to Save Darfur', 'U2', 'Pop', 16),
#  ("Kill 'Em All", 'Metallica', 'Metal', 16),
#  ('The Best Of Men At Work', 'Men At Work', 'Rock', 16),
#  ('Beyond Good And Evil', 'The Cult', 'Rock', 15),
#  ('Revelations', 'Audioslave', 'Alternative', 15),
#  ('Garage Inc. (Disc 2)', 'Metallica', 'Metal', 14),
#  ('How To Dismantle An Atomic Bomb', 'U2', 'Rock', 14),
#  ('Motley Crue Greatest Hits', 'Mötley Crüe', 'Metal', 14),
#  ('O Samba Poconé', 'Skank', 'Rock', 14),
#  ('Tribute', 'Ozzy Osbourne', 'Metal', 14),
#  ('Van Halen III', 'Van Halen', 'Rock', 14),
#  ('Speak of the Devil', 'Ozzy Osbourne', 'Rock', 12),
#  ('Stormbringer', 'Deep Purple', 'Rock', 12),
#  ('Alcohol Fueled Brewtality Live! [Disc 1]', 'Black Label Society', 'Metal', 11),
#  ('No Prayer For The Dying', 'Iron Maiden', 'Metal', 11)]

# %% [markdown]
# What we can interpret from the data is that the most popular genres for the store seem to be rock, alternative & punk and metal. Based on the popularity of these genres, next we take a look at the artists of the same genre's with the highest amount of tracks purchased. Threfore, it makes most sense to purchase more albums from artists:
# Jimi Hendrix (are you experienced) for Rock
# JET(get born) for Alternative and Punk
# Godsmack(Faceless) for Metal

# %% [markdown]
# However, since those aren't the options, we look at the next most popular genres. So we conclude to suggest buying albums from Red Tone(Punk), Meteor and the Girls(Pop) and Slim Jim  Bites(Blues)

# %% [markdown]
# # Sales support performance

# %%
# %%sql
#
# -- Mapping the sales support to the customers
#
# SELECT
#     e.employee_id employees,
#     e.first_name || " " || e.last_name agent_name,
#     c.customer_id customers,
#     c.first_name || " " || c.last_name customer_name
#
# FROM employee e
# INNER JOIN customer c ON e.employee_id = c.support_rep_id
# ORDER BY 1;
# Out:
# Done.
# [(3, 'Jane Peacock', 1, 'Luís Gonçalves'),
#  (3, 'Jane Peacock', 3, 'François Tremblay'),
#  (3, 'Jane Peacock', 12, 'Roberto Almeida'),
#  (3, 'Jane Peacock', 15, 'Jennifer Peterson'),
#  (3, 'Jane Peacock', 18, 'Michelle Brooks'),
#  (3, 'Jane Peacock', 19, 'Tim Goyer'),
#  (3, 'Jane Peacock', 24, 'Frank Ralston'),
#  (3, 'Jane Peacock', 29, 'Robert Brown'),
#  (3, 'Jane Peacock', 30, 'Edward Francis'),
#  (3, 'Jane Peacock', 33, 'Ellie Sullivan'),
#  (3, 'Jane Peacock', 37, 'Fynn Zimmermann'),
#  (3, 'Jane Peacock', 38, 'Niklas Schröder'),
#  (3, 'Jane Peacock', 42, 'Wyatt Girard'),
#  (3, 'Jane Peacock', 43, 'Isabelle Mercier'),
#  (3, 'Jane Peacock', 44, 'Terhi Hämäläinen'),
#  (3, 'Jane Peacock', 45, 'Ladislav Kovács'),
#  (3, 'Jane Peacock', 46, "Hugh O'Reilly"),
#  (3, 'Jane Peacock', 52, 'Emma Jones'),
#  (3, 'Jane Peacock', 53, 'Phil Hughes'),
#  (3, 'Jane Peacock', 58, 'Manoj Pareek'),
#  (3, 'Jane Peacock', 59, 'Puja Srivastava'),
#  (4, 'Margaret Park', 4, 'Bjørn Hansen'),
#  (4, 'Margaret Park', 5, 'František Wichterlová'),
#  (4, 'Margaret Park', 8, 'Daan Peeters'),
#  (4, 'Margaret Park', 9, 'Kara Nielsen'),
#  (4, 'Margaret Park', 10, 'Eduardo Martins'),
#  (4, 'Margaret Park', 13, 'Fernanda Ramos'),
#  (4, 'Margaret Park', 16, 'Frank Harris'),
#  (4, 'Margaret Park', 20, 'Dan Miller'),
#  (4, 'Margaret Park', 22, 'Heather Leacock'),
#  (4, 'Margaret Park', 23, 'John Gordon'),
#  (4, 'Margaret Park', 26, 'Richard Cunningham'),
#  (4, 'Margaret Park', 27, 'Patrick Gray'),
#  (4, 'Margaret Park', 32, 'Aaron Mitchell'),
#  (4, 'Margaret Park', 34, 'João Fernandes'),
#  (4, 'Margaret Park', 35, 'Madalena Sampaio'),
#  (4, 'Margaret Park', 39, 'Camille Bernard'),
#  (4, 'Margaret Park', 40, 'Dominique Lefebvre'),
#  (4, 'Margaret Park', 49, 'Stanisław Wójcik'),
#  (4, 'Margaret Park', 55, 'Mark Taylor'),
#  (4, 'Margaret Park', 56, 'Diego Gutiérrez'),
#  (5, 'Steve Johnson', 2, 'Leonie Köhler'),
#  (5, 'Steve Johnson', 6, 'Helena Holý'),
#  (5, 'Steve Johnson', 7, 'Astrid Gruber'),
#  (5, 'Steve Johnson', 11, 'Alexandre Rocha'),
#  (5, 'Steve Johnson', 14, 'Mark Philips'),
#  (5, 'Steve Johnson', 17, 'Jack Smith'),
#  (5, 'Steve Johnson', 21, 'Kathy Chase'),
#  (5, 'Steve Johnson', 25, 'Victor Stevens'),
#  (5, 'Steve Johnson', 28, 'Julia Barnett'),
#  (5, 'Steve Johnson', 31, 'Martha Silk'),
#  (5, 'Steve Johnson', 36, 'Hannah Schneider'),
#  (5, 'Steve Johnson', 41, 'Marc Dubois'),
#  (5, 'Steve Johnson', 47, 'Lucas Mancini'),
#  (5, 'Steve Johnson', 48, 'Johannes Van der Berg'),
#  (5, 'Steve Johnson', 50, 'Enrique Muñoz'),
#  (5, 'Steve Johnson', 51, 'Joakim Johansson'),
#  (5, 'Steve Johnson', 54, 'Steve Murray'),
#  (5, 'Steve Johnson', 57, 'Luis Rojas')]

# %%
# %%sql
#
# -- Finding the number of customers each sales support agent has
#
# SELECT
#     e.employee_id employees,
#     e.first_name || " " || e.last_name agent_name,
#     COUNT(c.customer_id)
# FROM employee e
# INNER JOIN customer c ON e.employee_id = c.support_rep_id
# GROUP BY 1;
# Out:
# Done.
# [(3, 'Jane Peacock', 21), (4, 'Margaret Park', 20), (5, 'Steve Johnson', 18)]

# %%
# %%sql
#
# -- Finding total expenditure by each customer
#
# SELECT
#     c.customer_id,
#     c.first_name || " " || c.last_name customer_name,
#     c.support_rep_id,
#     SUM(i.total) total_purchase_by_customer
# FROM customer c
# INNER JOIN invoice i ON c.customer_id = i.customer_id
# GROUP BY 1;
# Out:
# Done.
# [(1, 'Luís Gonçalves', 3, 108.89999999999998),
#  (2, 'Leonie Köhler', 5, 82.17),
#  (3, 'François Tremblay', 3, 99.99),
#  (4, 'Bjørn Hansen', 4, 72.27000000000001),
#  (5, 'František Wichterlová', 4, 144.54000000000002),
#  (6, 'Helena Holý', 5, 128.7),
#  (7, 'Astrid Gruber', 5, 69.3),
#  (8, 'Daan Peeters', 4, 60.38999999999999),
#  (9, 'Kara Nielsen', 4, 37.61999999999999),
#  (10, 'Eduardo Martins', 4, 60.39),
#  (11, 'Alexandre Rocha', 5, 69.3),
#  (12, 'Roberto Almeida', 3, 82.17),
#  (13, 'Fernanda Ramos', 4, 106.91999999999999),
#  (14, 'Mark Philips', 5, 29.699999999999996),
#  (15, 'Jennifer Peterson', 3, 66.33),
#  (16, 'Frank Harris', 4, 74.25),
#  (17, 'Jack Smith', 5, 98.01),
#  (18, 'Michelle Brooks', 3, 79.2),
#  (19, 'Tim Goyer', 3, 54.449999999999996),
#  (20, 'Dan Miller', 4, 95.03999999999999),
#  (21, 'Kathy Chase', 5, 91.08000000000001),
#  (22, 'Heather Leacock', 4, 92.07000000000001),
#  (23, 'John Gordon', 4, 66.33),
#  (24, 'Frank Ralston', 3, 71.28),
#  (25, 'Victor Stevens', 5, 76.23),
#  (26, 'Richard Cunningham', 4, 86.13000000000002),
#  (27, 'Patrick Gray', 4, 84.14999999999999),
#  (28, 'Julia Barnett', 5, 72.27),
#  (29, 'Robert Brown', 3, 40.59),
#  (30, 'Edward Francis', 3, 91.08),
#  (31, 'Martha Silk', 5, 62.370000000000005),
#  (32, 'Aaron Mitchell', 4, 70.28999999999999),
#  (33, 'Ellie Sullivan', 3, 75.24000000000001),
#  (34, 'João Fernandes', 4, 102.96000000000001),
#  (35, 'Madalena Sampaio', 4, 82.17),
#  (36, 'Hannah Schneider', 5, 85.14),
#  (37, 'Fynn Zimmermann', 3, 94.05000000000001),
#  (38, 'Niklas Schröder', 3, 73.25999999999999),
#  (39, 'Camille Bernard', 4, 79.2),
#  (40, 'Dominique Lefebvre', 4, 72.27),
#  (41, 'Marc Dubois', 5, 64.35),
#  (42, 'Wyatt Girard', 3, 99.99),
#  (43, 'Isabelle Mercier', 3, 73.25999999999999),
#  (44, 'Terhi Hämäläinen', 3, 79.2),
#  (45, 'Ladislav Kovács', 3, 78.21),
#  (46, "Hugh O'Reilly", 3, 114.83999999999997),
#  (47, 'Lucas Mancini', 5, 50.49),
#  (48, 'Johannes Van der Berg', 5, 65.34),
#  (49, 'Stanisław Wójcik', 4, 76.22999999999999),
#  (50, 'Enrique Muñoz', 5, 98.01),
#  (51, 'Joakim Johansson', 5, 75.24),
#  (52, 'Emma Jones', 3, 68.31),
#  (53, 'Phil Hughes', 3, 98.01),
#  (54, 'Steve Murray', 5, 79.2),
#  (55, 'Mark Taylor', 4, 81.18),
#  (56, 'Diego Gutiérrez', 4, 39.6),
#  (57, 'Luis Rojas', 5, 97.02000000000001),
#  (58, 'Manoj Pareek', 3, 111.86999999999999),
#  (59, 'Puja Srivastava', 3, 71.28)]

# %%
# %%sql
#
# -- Mapping sales agents to customers along their total purchase
#
# SELECT
#     e.employee_id employees,
#     e.first_name || " " || e.last_name "agent name" ,
#     SUM(ct.total_purchase_by_customer) "total sales by each agent",
#     e.hire_date "hire date"
# FROM employee e
# INNER JOIN (SELECT
#                 c.customer_id,
#                 c.first_name || " " || c.last_name customer_name,
#                 c.support_rep_id,
#                 SUM(i.total) total_purchase_by_customer
#             FROM customer c
#             INNER JOIN invoice i ON c.customer_id = i.customer_id
#             GROUP BY 1) ct ON e.employee_id = ct.support_rep_id
# GROUP BY 1;
# Out:
# Done.
# [(3, 'Jane Peacock', 1731.5099999999998, '2017-04-01 00:00:00'),
#  (4, 'Margaret Park', 1584.0000000000002, '2017-05-03 00:00:00'),
#  (5, 'Steve Johnson', 1393.92, '2017-10-17 00:00:00')]

# %% [markdown]
# We can see that Jane has the highest amount of sales made among the three agents. Margaret is in the middle of the pack and Steve Johnson has the lowest sales. The reason Jane has the highest sales could be because she had a head start. She was the first one hired followed by Margaret and then Steve. As Margaret had more time than Steve to learn the craft she could've had better skillset and more opportunities than Steve to make sales.

# %% [markdown]
# # Analyzing sales by Country

# %%
# %%sql
#
# -- total number of customers
#
# SELECT
#     country,
#     count(distinct customer_id)
#
# FROM customer
# Out:
# Done.
# [('India', 59)]

# %%
# %%sql
#
# -- total number of customers
#
# with first as(
# SELECT
#     country,
#     count(customer_id) total_customers
# FROM customer
# group by country
# ),
#
# -- Total value of sales
#
# second as(
# SELECT
#     c.country,
#     sum(i.total) total_sales
# from customer c
# inner join invoice i on c.customer_id = i.customer_id
# group by 1
# ),
#
# -- Total sales per customer
#
# third as(
# SELECT
#     c.country,
#     c.customer_id,
#     sum(i.total) sales_per_cust
# from customer c
# inner join invoice i on c.customer_id = i.customer_id
# group by 1
# ),
#
# -- Average value of sales per customer (per country)
#
# fourth as(
# SELECT
#     third.country,
#     avg(third.sales_per_cust) avg_sales_per_cust
# from third
# group by 1
# ),
#
# -- Average order value per country
#
# fifth as (
# SELECT
#     c.country,
#     avg(i.total) avg_sales
# from customer c
# inner join invoice i on c.customer_id = i.customer_id
# group by 1
# ),
#
# sixth as(
# SELECT
# CASE
# WHEN first.total_customers = 1 THEN 'Other'
# ELSE first.country
# END as country,
# sum(first.total_customers) all_customers,
# sum(second.total_sales) all_sales,
# avg(fifth.avg_sales) avg_invoice
# from first
# inner join second on second.country = first.country
# inner join fourth on fourth.country = first.country
# inner join fifth on fifth.country = first.country
# group by 1
# order by 3 desc
# )
#
# SELECT
#     *
# from (SELECT
#           sixth.*,
#           CASE
#               when sixth.country = 'Other' then 1
#               Else 0
#           END nations
#        FROM sixth)
# ORDER BY nations
# Out:
# Done.
# [('USA', 13, 1040.4899999999998, 7.942671755725189, 0),
#  ('Canada', 8, 535.5900000000001, 7.047236842105265, 0),
#  ('Brazil', 5, 427.68000000000006, 7.0111475409836075, 0),
#  ('France', 5, 389.0699999999999, 7.781399999999998, 0),
#  ('Germany', 4, 334.62, 8.161463414634147, 0),
#  ('Czech Republic', 2, 273.24000000000007, 9.108000000000002, 0),
#  ('United Kingdom', 3, 245.52, 8.768571428571429, 0),
#  ('Portugal', 2, 185.13000000000002, 6.383793103448276, 0),
#  ('India', 2, 183.14999999999998, 8.72142857142857, 0),
#  ('Other', 15, 1094.9399999999998, 7.445071062271063, 1)]

# %% [markdown]
# The data shows that USA is the biggest customer followed by Canada and Brazil.

# %% [markdown]
# # Album Vs Individual Tracks

# %%
# %%sql
#
# -- Finding the number tracks in an album
#
# SELECT
#     a.album_id,
#     count(t.track_id) number_of_tracks
# from album a
# inner join track t on a.album_id = t.album_id
# group by 1;
# Out:
# Done.
# [(1, 10),
#  (2, 1),
#  (3, 3),
#  (4, 8),
#  (5, 15),
#  (6, 13),
#  (7, 12),
#  (8, 14),
#  (9, 8),
#  (10, 14),
#  (11, 12),
#  (12, 12),
#  (13, 8),
#  (14, 13),
#  (15, 5),
#  (16, 7),
#  (17, 10),
#  (18, 17),
#  (19, 11),
#  (20, 11),
#  (21, 18),
#  (22, 3),
#  (23, 34),
#  (24, 23),
#  (25, 13),
#  (26, 17),
#  (27, 14),
#  (28, 10),
#  (29, 14),
#  (30, 14),
#  (31, 9),
#  (32, 14),
#  (33, 17),
#  (34, 17),
#  (35, 11),
#  (36, 17),
#  (37, 20),
#  (38, 12),
#  (39, 21),
#  (40, 12),
#  (41, 14),
#  (42, 14),
#  (43, 7),
#  (44, 6),
#  (45, 14),
#  (46, 13),
#  (47, 14),
#  (48, 13),
#  (49, 10),
#  (50, 4),
#  (51, 22),
#  (52, 15),
#  (53, 14),
#  (54, 20),
#  (55, 20),
#  (56, 15),
#  (57, 15),
#  (58, 9),
#  (59, 7),
#  (60, 7),
#  (61, 11),
#  (62, 7),
#  (63, 12),
#  (64, 9),
#  (65, 9),
#  (66, 10),
#  (67, 16),
#  (68, 9),
#  (69, 13),
#  (70, 13),
#  (71, 14),
#  (72, 18),
#  (73, 30),
#  (74, 12),
#  (75, 14),
#  (76, 15),
#  (77, 11),
#  (78, 14),
#  (79, 10),
#  (80, 10),
#  (81, 11),
#  (82, 13),
#  (83, 24),
#  (84, 16),
#  (85, 14),
#  (86, 15),
#  (87, 3),
#  (88, 12),
#  (89, 13),
#  (90, 12),
#  (91, 16),
#  (92, 14),
#  (93, 13),
#  (94, 11),
#  (95, 12),
#  (96, 11),
#  (97, 10),
#  (98, 11),
#  (99, 12),
#  (100, 9),
#  (101, 10),
#  (102, 18),
#  (103, 10),
#  (104, 10),
#  (105, 10),
#  (106, 9),
#  (107, 8),
#  (108, 10),
#  (109, 9),
#  (110, 8),
#  (111, 8),
#  (112, 8),
#  (113, 11),
#  (114, 8),
#  (115, 20),
#  (116, 10),
#  (117, 11),
#  (118, 11),
#  (119, 13),
#  (120, 17),
#  (121, 10),
#  (122, 14),
#  (123, 12),
#  (124, 14),
#  (125, 16),
#  (126, 15),
#  (127, 10),
#  (128, 8),
#  (129, 8),
#  (130, 7),
#  (131, 8),
#  (132, 9),
#  (133, 9),
#  (134, 10),
#  (135, 9),
#  (136, 7),
#  (137, 5),
#  (138, 4),
#  (139, 15),
#  (140, 16),
#  (141, 57),
#  (142, 14),
#  (143, 14),
#  (144, 10),
#  (145, 18),
#  (146, 18),
#  (147, 10),
#  (148, 12),
#  (149, 16),
#  (150, 10),
#  (151, 14),
#  (152, 8),
#  (153, 13),
#  (154, 8),
#  (155, 11),
#  (156, 9),
#  (157, 14),
#  (158, 13),
#  (159, 13),
#  (160, 15),
#  (161, 12),
#  (162, 17),
#  (163, 17),
#  (164, 12),
#  (165, 15),
#  (166, 14),
#  (167, 21),
#  (168, 12),
#  (169, 16),
#  (170, 1),
#  (171, 2),
#  (172, 1),
#  (173, 2),
#  (174, 14),
#  (175, 12),
#  (176, 14),
#  (177, 10),
#  (178, 16),
#  (179, 13),
#  (180, 15),
#  (181, 11),
#  (182, 12),
#  (183, 9),
#  (184, 16),
#  (185, 17),
#  (186, 11),
#  (187, 11),
#  (188, 11),
#  (189, 14),
#  (190, 16),
#  (191, 10),
#  (192, 14),
#  (193, 17),
#  (194, 16),
#  (195, 15),
#  (196, 14),
#  (197, 8),
#  (198, 6),
#  (199, 12),
#  (200, 11),
#  (201, 16),
#  (202, 18),
#  (203, 17),
#  (204, 9),
#  (205, 10),
#  (206, 12),
#  (207, 11),
#  (208, 7),
#  (209, 10),
#  (210, 9),
#  (211, 18),
#  (212, 12),
#  (213, 18),
#  (214, 11),
#  (215, 14),
#  (216, 12),
#  (217, 14),
#  (218, 15),
#  (219, 15),
#  (220, 11),
#  (221, 20),
#  (222, 15),
#  (223, 15),
#  (224, 22),
#  (225, 16),
#  (226, 1),
#  (227, 19),
#  (228, 23),
#  (229, 26),
#  (230, 25),
#  (231, 24),
#  (232, 12),
#  (233, 11),
#  (234, 15),
#  (235, 11),
#  (236, 12),
#  (237, 17),
#  (238, 14),
#  (239, 10),
#  (240, 10),
#  (241, 14),
#  (242, 12),
#  (243, 17),
#  (244, 11),
#  (245, 12),
#  (246, 13),
#  (247, 15),
#  (248, 19),
#  (249, 6),
#  (250, 22),
#  (251, 25),
#  (252, 1),
#  (253, 24),
#  (254, 1),
#  (255, 23),
#  (256, 12),
#  (257, 12),
#  (258, 19),
#  (259, 17),
#  (260, 1),
#  (261, 17),
#  (262, 2),
#  (263, 2),
#  (264, 2),
#  (265, 2),
#  (266, 1),
#  (267, 1),
#  (268, 1),
#  (269, 10),
#  (270, 14),
#  (271, 14),
#  (272, 1),
#  (273, 1),
#  (274, 1),
#  (275, 1),
#  (276, 1),
#  (277, 1),
#  (278, 1),
#  (279, 1),
#  (280, 2),
#  (281, 1),
#  (282, 1),
#  (283, 1),
#  (284, 1),
#  (285, 1),
#  (286, 1),
#  (287, 1),
#  (288, 1),
#  (289, 1),
#  (290, 1),
#  (291, 1),
#  (292, 1),
#  (293, 1),
#  (294, 1),
#  (295, 1),
#  (296, 1),
#  (297, 1),
#  (298, 1),
#  (299, 1),
#  (300, 1),
#  (301, 1),
#  (302, 1),
#  (303, 1),
#  (304, 1),
#  (305, 1),
#  (306, 1),
#  (307, 1),
#  (308, 1),
#  (309, 1),
#  (310, 1),
#  (311, 1),
#  (312, 1),
#  (313, 1),
#  (314, 2),
#  (315, 1),
#  (316, 1),
#  (317, 1),
#  (318, 1),
#  (319, 1),
#  (320, 1),
#  (321, 12),
#  (322, 11),
#  (323, 1),
#  (324, 1),
#  (325, 1),
#  (326, 1),
#  (327, 1),
#  (328, 1),
#  (329, 1),
#  (330, 1),
#  (331, 1),
#  (332, 1),
#  (333, 1),
#  (334, 1),
#  (335, 1),
#  (336, 1),
#  (337, 1),
#  (338, 1),
#  (339, 1),
#  (340, 1),
#  (341, 1),
#  (342, 1),
#  (343, 1),
#  (344, 1),
#  (345, 1),
#  (346, 1),
#  (347, 1)]

# %%
# %%sql
#
# -- Total tracks per invoice
#
# SELECT
#     i.invoice_id,
#     count(il.track_id) total_tracks_per_invoice
# from invoice i
# inner join invoice_line il on i.invoice_id = il.invoice_id
# group by 1;
# Out:
# Done.
# [(1, 16),
#  (2, 10),
#  (3, 2),
#  (4, 8),
#  (5, 17),
#  (6, 2),
#  (7, 11),
#  (8, 10),
#  (9, 9),
#  (10, 2),
#  (11, 11),
#  (12, 4),
#  (13, 1),
#  (14, 1),
#  (15, 4),
#  (16, 9),
#  (17, 11),
#  (18, 5),
#  (19, 7),
#  (20, 10),
#  (21, 9),
#  (22, 2),
#  (23, 10),
#  (24, 12),
#  (25, 8),
#  (26, 2),
#  (27, 8),
#  (28, 3),
#  (29, 6),
#  (30, 11),
#  (31, 20),
#  (32, 13),
#  (33, 4),
#  (34, 1),
#  (35, 5),
#  (36, 7),
#  (37, 10),
#  (38, 7),
#  (39, 8),
#  (40, 10),
#  (41, 8),
#  (42, 9),
#  (43, 7),
#  (44, 12),
#  (45, 8),
#  (46, 11),
#  (47, 6),
#  (48, 4),
#  (49, 5),
#  (50, 7),
#  (51, 8),
#  (52, 12),
#  (53, 3),
#  (54, 18),
#  (55, 10),
#  (56, 17),
#  (57, 1),
#  (58, 6),
#  (59, 11),
#  (60, 8),
#  (61, 12),
#  (62, 3),
#  (63, 6),
#  (64, 13),
#  (65, 2),
#  (66, 7),
#  (67, 11),
#  (68, 11),
#  (69, 14),
#  (70, 1),
#  (71, 17),
#  (72, 3),
#  (73, 15),
#  (74, 2),
#  (75, 4),
#  (76, 13),
#  (77, 6),
#  (78, 9),
#  (79, 14),
#  (80, 1),
#  (81, 6),
#  (82, 7),
#  (83, 4),
#  (84, 12),
#  (85, 5),
#  (86, 1),
#  (87, 8),
#  (88, 5),
#  (89, 2),
#  (90, 11),
#  (91, 11),
#  (92, 20),
#  (93, 10),
#  (94, 8),
#  (95, 11),
#  (96, 6),
#  (97, 6),
#  (98, 10),
#  (99, 18),
#  (100, 6),
#  (101, 4),
#  (102, 10),
#  (103, 6),
#  (104, 2),
#  (105, 8),
#  (106, 8),
#  (107, 11),
#  (108, 5),
#  (109, 11),
#  (110, 6),
#  (111, 5),
#  (112, 17),
#  (113, 10),
#  (114, 17),
#  (115, 9),
#  (116, 11),
#  (117, 11),
#  (118, 1),
#  (119, 2),
#  (120, 6),
#  (121, 9),
#  (122, 5),
#  (123, 12),
#  (124, 6),
#  (125, 10),
#  (126, 4),
#  (127, 11),
#  (128, 7),
#  (129, 11),
#  (130, 4),
#  (131, 3),
#  (132, 2),
#  (133, 10),
#  (134, 8),
#  (135, 3),
#  (136, 4),
#  (137, 2),
#  (138, 11),
#  (139, 5),
#  (140, 8),
#  (141, 18),
#  (142, 15),
#  (143, 5),
#  (144, 3),
#  (145, 5),
#  (146, 13),
#  (147, 5),
#  (148, 9),
#  (149, 9),
#  (150, 3),
#  (151, 3),
#  (152, 6),
#  (153, 14),
#  (154, 3),
#  (155, 9),
#  (156, 11),
#  (157, 1),
#  (158, 6),
#  (159, 6),
#  (160, 9),
#  (161, 8),
#  (162, 9),
#  (163, 9),
#  (164, 4),
#  (165, 8),
#  (166, 10),
#  (167, 6),
#  (168, 6),
#  (169, 9),
#  (170, 10),
#  (171, 13),
#  (172, 8),
#  (173, 11),
#  (174, 7),
#  (175, 18),
#  (176, 7),
#  (177, 2),
#  (178, 3),
#  (179, 10),
#  (180, 10),
#  (181, 7),
#  (182, 6),
#  (183, 24),
#  (184, 1),
#  (185, 9),
#  (186, 3),
#  (187, 7),
#  (188, 11),
#  (189, 4),
#  (190, 5),
#  (191, 4),
#  (192, 9),
#  (193, 2),
#  (194, 1),
#  (195, 11),
#  (196, 10),
#  (197, 11),
#  (198, 11),
#  (199, 3),
#  (200, 8),
#  (201, 12),
#  (202, 2),
#  (203, 10),
#  (204, 11),
#  (205, 10),
#  (206, 5),
#  (207, 4),
#  (208, 6),
#  (209, 4),
#  (210, 11),
#  (211, 9),
#  (212, 12),
#  (213, 11),
#  (214, 5),
#  (215, 2),
#  (216, 5),
#  (217, 10),
#  (218, 9),
#  (219, 3),
#  (220, 9),
#  (221, 8),
#  (222, 2),
#  (223, 18),
#  (224, 10),
#  (225, 6),
#  (226, 11),
#  (227, 10),
#  (228, 4),
#  (229, 3),
#  (230, 8),
#  (231, 3),
#  (232, 4),
#  (233, 6),
#  (234, 1),
#  (235, 7),
#  (236, 3),
#  (237, 16),
#  (238, 10),
#  (239, 16),
#  (240, 3),
#  (241, 2),
#  (242, 10),
#  (243, 11),
#  (244, 5),
#  (245, 3),
#  (246, 9),
#  (247, 11),
#  (248, 7),
#  (249, 2),
#  (250, 11),
#  (251, 7),
#  (252, 8),
#  (253, 12),
#  (254, 10),
#  (255, 4),
#  (256, 5),
#  (257, 11),
#  (258, 1),
#  (259, 7),
#  (260, 8),
#  (261, 9),
#  (262, 8),
#  (263, 5),
#  (264, 1),
#  (265, 7),
#  (266, 6),
#  (267, 2),
#  (268, 11),
#  (269, 1),
#  (270, 11),
#  (271, 11),
#  (272, 9),
#  (273, 17),
#  (274, 5),
#  (275, 8),
#  (276, 19),
#  (277, 5),
#  (278, 3),
#  (279, 5),
#  (280, 11),
#  (281, 14),
#  (282, 17),
#  (283, 9),
#  (284, 11),
#  (285, 10),
#  (286, 2),
#  (287, 2),
#  (288, 11),
#  (289, 7),
#  (290, 5),
#  (291, 3),
#  (292, 10),
#  (293, 5),
#  (294, 11),
#  (295, 1),
#  (296, 13),
#  (297, 3),
#  (298, 9),
#  (299, 6),
#  (300, 12),
#  (301, 8),
#  (302, 4),
#  (303, 10),
#  (304, 7),
#  (305, 15),
#  (306, 11),
#  (307, 10),
#  (308, 11),
#  (309, 9),
#  (310, 9),
#  (311, 6),
#  (312, 10),
#  (313, 5),
#  (314, 10),
#  (315, 5),
#  (316, 2),
#  (317, 12),
#  (318, 8),
#  (319, 10),
#  (320, 17),
#  (321, 1),
#  (322, 10),
#  (323, 8),
#  (324, 5),
#  (325, 10),
#  (326, 9),
#  (327, 9),
#  (328, 4),
#  (329, 1),
#  (330, 13),
#  (331, 6),
#  (332, 10),
#  (333, 6),
#  (334, 15),
#  (335, 15),
#  (336, 16),
#  (337, 10),
#  (338, 5),
#  (339, 8),
#  (340, 3),
#  (341, 12),
#  (342, 3),
#  (343, 6),
#  (344, 17),
#  (345, 10),
#  (346, 6),
#  (347, 4),
#  (348, 9),
#  (349, 1),
#  (350, 3),
#  (351, 10),
#  (352, 1),
#  (353, 10),
#  (354, 5),
#  (355, 7),
#  (356, 7),
#  (357, 3),
#  (358, 7),
#  (359, 9),
#  (360, 4),
#  (361, 2),
#  (362, 20),
#  (363, 3),
#  (364, 6),
#  (365, 4),
#  (366, 9),
#  (367, 8),
#  (368, 2),
#  (369, 10),
#  (370, 9),
#  (371, 1),
#  (372, 14),
#  (373, 4),
#  (374, 6),
#  (375, 9),
#  (376, 4),
#  (377, 3),
#  (378, 4),
#  (379, 12),
#  (380, 10),
#  (381, 13),
#  (382, 4),
#  (383, 10),
#  (384, 11),
#  (385, 7),
#  (386, 5),
#  (387, 6),
#  (388, 10),
#  (389, 17),
#  (390, 3),
#  (391, 4),
#  (392, 8),
#  (393, 11),
#  (394, 8),
#  (395, 10),
#  (396, 9),
#  (397, 7),
#  (398, 17),
#  (399, 12),
#  (400, 4),
#  (401, 10),
#  (402, 9),
#  (403, 9),
#  (404, 14),
#  (405, 8),
#  (406, 2),
#  (407, 10),
#  (408, 6),
#  (409, 11),
#  (410, 4),
#  (411, 2),
#  (412, 8),
#  (413, 15),
#  (414, 10),
#  (415, 9),
#  (416, 1),
#  (417, 10),
#  (418, 1),
#  (419, 10),
#  (420, 10),
#  (421, 8),
#  (422, 7),
#  (423, 11),
#  (424, 2),
#  (425, 1),
#  (426, 5),
#  (427, 15),
#  (428, 4),
#  (429, 11),
#  (430, 2),
#  (431, 10),
#  (432, 2),
#  (433, 3),
#  (434, 10),
#  (435, 6),
#  (436, 6),
#  (437, 10),
#  (438, 11),
#  (439, 7),
#  (440, 3),
#  (441, 7),
#  (442, 4),
#  (443, 8),
#  (444, 9),
#  (445, 4),
#  (446, 9),
#  (447, 11),
#  (448, 10),
#  (449, 17),
#  (450, 7),
#  (451, 1),
#  (452, 8),
#  (453, 5),
#  (454, 15),
#  (455, 5),
#  (456, 10),
#  (457, 15),
#  (458, 1),
#  (459, 2),
#  (460, 11),
#  (461, 8),
#  (462, 9),
#  (463, 12),
#  (464, 4),
#  (465, 7),
#  (466, 4),
#  (467, 10),
#  (468, 16),
#  (469, 1),
#  (470, 2),
#  (471, 1),
#  (472, 3),
#  (473, 4),
#  (474, 7),
#  (475, 8),
#  (476, 11),
#  (477, 7),
#  (478, 17),
#  (479, 17),
#  (480, 10),
#  (481, 4),
#  (482, 8),
#  (483, 5),
#  (484, 3),
#  (485, 10),
#  (486, 9),
#  (487, 10),
#  (488, 14),
#  (489, 3),
#  (490, 9),
#  (491, 2),
#  (492, 5),
#  (493, 4),
#  (494, 10),
#  (495, 1),
#  (496, 8),
#  (497, 7),
#  (498, 4),
#  (499, 10),
#  (500, 9),
#  (501, 13),
#  (502, 4),
#  (503, 10),
#  (504, 11),
#  (505, 1),
#  (506, 16),
#  (507, 1),
#  (508, 9),
#  (509, 7),
#  (510, 10),
#  (511, 7),
#  (512, 9),
#  (513, 11),
#  (514, 3),
#  (515, 3),
#  (516, 2),
#  (517, 9),
#  (518, 2),
#  (519, 7),
#  (520, 10),
#  (521, 4),
#  (522, 8),
#  (523, 8),
#  (524, 5),
#  (525, 10),
#  (526, 20),
#  (527, 11),
#  (528, 16),
#  (529, 14),
#  (530, 1),
#  (531, 12),
#  (532, 14),
#  (533, 13),
#  (534, 6),
#  (535, 1),
#  (536, 6),
#  (537, 8),
#  (538, 9),
#  (539, 1),
#  (540, 11),
#  (541, 3),
#  (542, 11),
#  (543, 3),
#  (544, 9),
#  (545, 8),
#  (546, 7),
#  (547, 10),
#  (548, 11),
#  (549, 11),
#  (550, 10),
#  (551, 11),
#  (552, 6),
#  (553, 5),
#  (554, 9),
#  (555, 2),
#  (556, 11),
#  (557, 10),
#  (558, 11),
#  (559, 6),
#  (560, 9),
#  (561, 7),
#  (562, 9),
#  (563, 2),
#  (564, 6),
#  (565, 10),
#  (566, 5),
#  (567, 8),
#  (568, 7),
#  (569, 1),
#  (570, 3),
#  (571, 3),
#  (572, 5),
#  (573, 11),
#  (574, 11),
#  (575, 4),
#  (576, 6),
#  (577, 9),
#  (578, 12),
#  (579, 11),
#  (580, 10),
#  (581, 14),
#  (582, 18),
#  (583, 11),
#  (584, 1),
#  (585, 9),
#  (586, 11),
#  (587, 2),
#  (588, 1),
#  (589, 11),
#  (590, 9),
#  (591, 7),
#  (592, 8),
#  (593, 11),
#  (594, 3),
#  (595, 8),
#  (596, 6),
#  (597, 7),
#  (598, 5),
#  (599, 8),
#  (600, 5),
#  (601, 11),
#  (602, 7),
#  (603, 5),
#  (604, 18),
#  (605, 4),
#  (606, 12),
#  (607, 5),
#  (608, 1),
#  (609, 3),
#  (610, 7),
#  (611, 2),
#  (612, 12),
#  (613, 9),
#  (614, 13)]

# %%
# %%sql
# select * from invoice_line
# Out:
# Done.
# [(1, 1, 1158, 0.99, 1),
#  (2, 1, 1159, 0.99, 1),
#  (3, 1, 1160, 0.99, 1),
#  (4, 1, 1161, 0.99, 1),
#  (5, 1, 1162, 0.99, 1),
#  (6, 1, 1163, 0.99, 1),
#  (7, 1, 1164, 0.99, 1),
#  (8, 1, 1165, 0.99, 1),
#  (9, 1, 1166, 0.99, 1),
#  (10, 1, 1167, 0.99, 1),
#  (11, 1, 1168, 0.99, 1),
#  (12, 1, 1169, 0.99, 1),
#  (13, 1, 1170, 0.99, 1),
#  (14, 1, 1171, 0.99, 1),
#  (15, 1, 1172, 0.99, 1),
#  (16, 1, 1173, 0.99, 1),
#  (17, 2, 3476, 0.99, 1),
#  (18, 2, 482, 0.99, 1),
#  (19, 2, 2701, 0.99, 1),
#  (20, 2, 1641, 0.99, 1),
#  (21, 2, 1119, 0.99, 1),
#  (22, 2, 2324, 0.99, 1),
#  (23, 2, 201, 0.99, 1),
#  (24, 2, 819, 0.99, 1),
#  (25, 2, 392, 0.99, 1),
#  (26, 2, 2651, 0.99, 1),
#  (27, 3, 2516, 0.99, 1),
#  (28, 3, 2646, 0.99, 1),
#  (29, 4, 3448, 0.99, 1),
#  (30, 4, 2560, 0.99, 1),
#  (31, 4, 3336, 0.99, 1),
#  (32, 4, 829, 0.99, 1),
#  (33, 4, 1872, 0.99, 1),
#  (34, 4, 748, 0.99, 1),
#  (35, 4, 1778, 0.99, 1),
#  (36, 4, 2514, 0.99, 1),
#  (37, 5, 1986, 0.99, 1),
#  (38, 5, 1987, 0.99, 1),
#  (39, 5, 1988, 0.99, 1),
#  (40, 5, 1989, 0.99, 1),
#  (41, 5, 1990, 0.99, 1),
#  (42, 5, 1991, 0.99, 1),
#  (43, 5, 1992, 0.99, 1),
#  (44, 5, 1993, 0.99, 1),
#  (45, 5, 1994, 0.99, 1),
#  (46, 5, 1995, 0.99, 1),
#  (47, 5, 1996, 0.99, 1),
#  (48, 5, 1997, 0.99, 1),
#  (49, 5, 1998, 0.99, 1),
#  (50, 5, 1999, 0.99, 1),
#  (51, 5, 2000, 0.99, 1),
#  (52, 5, 2001, 0.99, 1),
#  (53, 5, 2002, 0.99, 1),
#  (54, 6, 1045, 0.99, 1),
#  (55, 6, 30, 0.99, 1),
#  (56, 7, 3477, 0.99, 1),
#  (57, 7, 3439, 0.99, 1),
#  (58, 7, 1102, 0.99, 1),
#  (59, 7, 711, 0.99, 1),
#  (60, 7, 1988, 0.99, 1),
#  (61, 7, 3024, 0.99, 1),
#  (62, 7, 834, 0.99, 1),
#  (63, 7, 2596, 0.99, 1),
#  (64, 7, 1343, 0.99, 1),
#  (65, 7, 2644, 0.99, 1),
#  (66, 7, 42, 0.99, 1),
#  (67, 8, 2231, 0.99, 1),
#  (68, 8, 2509, 0.99, 1),
#  (69, 8, 81, 0.99, 1),
#  (70, 8, 1758, 0.99, 1),
#  (71, 8, 1455, 0.99, 1),
#  (72, 8, 2946, 0.99, 1),
#  (73, 8, 574, 0.99, 1),
#  (74, 8, 1752, 0.99, 1),
#  (75, 8, 2263, 0.99, 1),
#  (76, 8, 1560, 0.99, 1),
#  (77, 9, 206, 0.99, 1),
#  (78, 9, 3456, 0.99, 1),
#  (79, 9, 1041, 0.99, 1),
#  (80, 9, 1279, 0.99, 1),
#  (81, 9, 2098, 0.99, 1),
#  (82, 9, 3399, 0.99, 1),
#  (83, 9, 1983, 0.99, 1),
#  (84, 9, 993, 0.99, 1),
#  (85, 9, 196, 0.99, 1),
#  (86, 10, 2663, 0.99, 1),
#  (87, 10, 3290, 0.99, 1),
#  (88, 11, 2597, 0.99, 1),
#  (89, 11, 2203, 0.99, 1),
#  (90, 11, 2420, 0.99, 1),
#  (91, 11, 2643, 0.99, 1),
#  (92, 11, 3072, 0.99, 1),
#  (93, 11, 1138, 0.99, 1),
#  (94, 11, 2391, 0.99, 1),
#  (95, 11, 2257, 0.99, 1),
#  (96, 11, 610, 0.99, 1),
#  (97, 11, 1419, 0.99, 1),
#  (98, 11, 3452, 0.99, 1),
#  (99, 12, 1463, 0.99, 1),
#  (100, 12, 690, 0.99, 1),
#  (101, 12, 2663, 0.99, 1),
#  (102, 12, 92, 0.99, 1),
#  (103, 13, 2553, 0.99, 1),
#  (104, 14, 541, 0.99, 1),
#  (105, 15, 3050, 0.99, 1),
#  (106, 15, 1489, 0.99, 1),
#  (107, 15, 807, 0.99, 1),
#  (108, 15, 3336, 0.99, 1),
#  (109, 16, 2160, 0.99, 1),
#  (110, 16, 875, 0.99, 1),
#  (111, 16, 83, 0.99, 1),
#  (112, 16, 16, 0.99, 1),
#  (113, 16, 1756, 0.99, 1),
#  (114, 16, 3460, 0.99, 1),
#  (115, 16, 93, 0.99, 1),
#  (116, 16, 24, 0.99, 1),
#  (117, 16, 21, 0.99, 1),
#  (118, 17, 2400, 0.99, 1),
#  (119, 17, 1610, 0.99, 1),
#  (120, 17, 1973, 0.99, 1),
#  (121, 17, 2553, 0.99, 1),
#  (122, 17, 59, 0.99, 1),
#  (123, 17, 2270, 0.99, 1),
#  (124, 17, 55, 0.99, 1),
#  (125, 17, 2564, 0.99, 1),
#  (126, 17, 2171, 0.99, 1),
#  (127, 17, 2522, 0.99, 1),
#  (128, 17, 1419, 0.99, 1),
#  (129, 18, 1027, 0.99, 1),
#  (130, 18, 3142, 0.99, 1),
#  (131, 18, 1583, 0.99, 1),
#  (132, 18, 1752, 0.99, 1),
#  (133, 18, 2736, 0.99, 1),
#  (134, 19, 105, 0.99, 1),
#  (135, 19, 2669, 0.99, 1),
#  (136, 19, 1784, 0.99, 1),
#  (137, 19, 3460, 0.99, 1),
#  (138, 19, 2640, 0.99, 1),
#  (139, 19, 1310, 0.99, 1),
#  (140, 19, 2510, 0.99, 1),
#  (141, 20, 905, 0.99, 1),
#  (142, 20, 102, 0.99, 1),
#  (143, 20, 3336, 0.99, 1),
#  (144, 20, 1132, 0.99, 1),
#  (145, 20, 337, 0.99, 1),
#  (146, 20, 60, 0.99, 1),
#  (147, 20, 3357, 0.99, 1),
#  (148, 20, 3225, 0.99, 1),
#  (149, 20, 3297, 0.99, 1),
#  (150, 20, 3297, 0.99, 1),
#  (151, 21, 1461, 0.99, 1),
#  (152, 21, 2556, 0.99, 1),
#  (153, 21, 1434, 0.99, 1),
#  (154, 21, 3135, 0.99, 1),
#  (155, 21, 1473, 0.99, 1),
#  (156, 21, 1502, 0.99, 1),
#  (157, 21, 13, 0.99, 1),
#  (158, 21, 2971, 0.99, 1),
#  (159, 21, 2561, 0.99, 1),
#  (160, 22, 1000, 0.99, 1),
#  (161, 22, 383, 0.99, 1),
#  (162, 23, 1, 0.99, 1),
#  (163, 23, 6, 0.99, 1),
#  (164, 23, 7, 0.99, 1),
#  (165, 23, 8, 0.99, 1),
#  (166, 23, 9, 0.99, 1),
#  (167, 23, 10, 0.99, 1),
#  (168, 23, 11, 0.99, 1),
#  (169, 23, 12, 0.99, 1),
#  (170, 23, 13, 0.99, 1),
#  (171, 23, 14, 0.99, 1),
#  (172, 24, 1146, 0.99, 1),
#  (173, 24, 1147, 0.99, 1),
#  (174, 24, 1148, 0.99, 1),
#  (175, 24, 1149, 0.99, 1),
#  (176, 24, 1150, 0.99, 1),
#  (177, 24, 1151, 0.99, 1),
#  (178, 24, 1152, 0.99, 1),
#  (179, 24, 1153, 0.99, 1),
#  (180, 24, 1154, 0.99, 1),
#  (181, 24, 1155, 0.99, 1),
#  (182, 24, 1156, 0.99, 1),
#  (183, 24, 1157, 0.99, 1),
#  (184, 25, 46, 0.99, 1),
#  (185, 25, 948, 0.99, 1),
#  (186, 25, 2185, 0.99, 1),
#  (187, 25, 3049, 0.99, 1),
#  (188, 25, 1167, 0.99, 1),
#  (189, 25, 32, 0.99, 1),
#  (190, 25, 1800, 0.99, 1),
#  (191, 25, 1477, 0.99, 1),
#  (192, 26, 2670, 0.99, 1),
#  (193, 26, 85, 0.99, 1),
#  (194, 27, 3439, 0.99, 1),
#  (195, 27, 3014, 0.99, 1),
#  (196, 27, 1280, 0.99, 1),
#  (197, 27, 1496, 0.99, 1),
#  (198, 27, 2229, 0.99, 1),
#  (199, 27, 1445, 0.99, 1),
#  (200, 27, 2230, 0.99, 1),
#  (201, 27, 3105, 0.99, 1),
#  (202, 28, 36, 0.99, 1),
#  (203, 28, 3456, 0.99, 1),
#  (204, 28, 932, 0.99, 1),
#  (205, 29, 1025, 0.99, 1),
#  (206, 29, 2462, 0.99, 1),
#  (207, 29, 3341, 0.99, 1),
#  (208, 29, 1626, 0.99, 1),
#  (209, 29, 2395, 0.99, 1),
#  (210, 29, 479, 0.99, 1),
#  (211, 30, 919, 0.99, 1),
#  (212, 30, 3461, 0.99, 1),
#  (213, 30, 33, 0.99, 1),
#  (214, 30, 2341, 0.99, 1),
#  (215, 30, 1139, 0.99, 1),
#  (216, 30, 3109, 0.99, 1),
#  (217, 30, 2013, 0.99, 1),
#  (218, 30, 990, 0.99, 1),
#  (219, 30, 2413, 0.99, 1),
#  (220, 30, 2396, 0.99, 1),
#  (221, 30, 3464, 0.99, 1),
#  (222, 31, 2731, 0.99, 1),
#  (223, 31, 2732, 0.99, 1),
#  (224, 31, 2733, 0.99, 1),
#  (225, 31, 2734, 0.99, 1),
#  (226, 31, 2735, 0.99, 1),
#  (227, 31, 2736, 0.99, 1),
#  (228, 31, 2737, 0.99, 1),
#  (229, 31, 2738, 0.99, 1),
#  (230, 31, 2739, 0.99, 1),
#  (231, 31, 2740, 0.99, 1),
#  (232, 31, 2741, 0.99, 1),
#  (233, 31, 2742, 0.99, 1),
#  (234, 31, 2743, 0.99, 1),
#  (235, 31, 2744, 0.99, 1),
#  (236, 31, 2745, 0.99, 1),
#  (237, 31, 2746, 0.99, 1),
#  (238, 31, 2747, 0.99, 1),
#  (239, 31, 2748, 0.99, 1),
#  (240, 31, 2749, 0.99, 1),
#  (241, 31, 2750, 0.99, 1),
#  (242, 32, 38, 0.99, 1),
#  (243, 32, 39, 0.99, 1),
#  (244, 32, 40, 0.99, 1),
#  (245, 32, 41, 0.99, 1),
#  (246, 32, 42, 0.99, 1),
#  (247, 32, 43, 0.99, 1),
#  (248, 32, 44, 0.99, 1),
#  (249, 32, 45, 0.99, 1),
#  (250, 32, 46, 0.99, 1),
#  (251, 32, 47, 0.99, 1),
#  (252, 32, 48, 0.99, 1),
#  (253, 32, 49, 0.99, 1),
#  (254, 32, 50, 0.99, 1),
#  (255, 33, 3307, 0.99, 1),
#  (256, 33, 2736, 0.99, 1),
#  (257, 33, 2542, 0.99, 1),
#  (258, 33, 2697, 0.99, 1),
#  (259, 34, 610, 0.99, 1),
#  (260, 35, 2377, 0.99, 1),
#  (261, 35, 80, 0.99, 1),
#  (262, 35, 836, 0.99, 1),
#  (263, 35, 6, 0.99, 1),
#  (264, 35, 3475, 0.99, 1),
#  (265, 36, 1582, 0.99, 1),
#  (266, 36, 968, 0.99, 1),
#  (267, 36, 2233, 0.99, 1),
#  (268, 36, 153, 0.99, 1),
#  (269, 36, 1493, 0.99, 1),
#  (270, 36, 2656, 0.99, 1),
#  (271, 36, 1168, 0.99, 1),
#  (272, 37, 3458, 0.99, 1),
#  (273, 37, 1428, 0.99, 1),
#  (274, 37, 3329, 0.99, 1),
#  (275, 37, 698, 0.99, 1),
#  (276, 37, 1014, 0.99, 1),
#  (277, 37, 3336, 0.99, 1),
#  (278, 37, 3297, 0.99, 1),
#  (279, 37, 1166, 0.99, 1),
#  (280, 37, 3392, 0.99, 1),
#  (281, 37, 1763, 0.99, 1),
#  (282, 38, 2960, 0.99, 1),
#  (283, 38, 154, 0.99, 1),
#  (284, 38, 3272, 0.99, 1),
#  (285, 38, 2557, 0.99, 1),
#  (286, 38, 1566, 0.99, 1),
#  (287, 38, 1472, 0.99, 1),
#  (288, 38, 3409, 0.99, 1),
#  (289, 39, 2308, 0.99, 1),
#  (290, 39, 1669, 0.99, 1),
#  (291, 39, 2415, 0.99, 1),
#  (292, 39, 3142, 0.99, 1),
#  (293, 39, 3366, 0.99, 1),
#  (294, 39, 184, 0.99, 1),
#  (295, 39, 2519, 0.99, 1),
#  (296, 39, 3424, 0.99, 1),
#  (297, 40, 2382, 0.99, 1),
#  (298, 40, 2654, 0.99, 1),
#  (299, 40, 2556, 0.99, 1),
#  (300, 40, 108, 0.99, 1),
#  (301, 40, 553, 0.99, 1),
#  (302, 40, 2737, 0.99, 1),
#  (303, 40, 686, 0.99, 1),
#  (304, 40, 1626, 0.99, 1),
#  (305, 40, 3460, 0.99, 1),
#  (306, 40, 2237, 0.99, 1),
#  (307, 41, 153, 0.99, 1),
#  (308, 41, 3457, 0.99, 1),
#  (309, 41, 2511, 0.99, 1),
#  (310, 41, 2698, 0.99, 1),
#  (311, 41, 2945, 0.99, 1),
#  (312, 41, 1947, 0.99, 1),
#  (313, 41, 3336, 0.99, 1),
#  (314, 41, 773, 0.99, 1),
#  (315, 42, 2646, 0.99, 1),
#  (316, 42, 3074, 0.99, 1),
#  (317, 42, 711, 0.99, 1),
#  (318, 42, 13, 0.99, 1),
#  (319, 42, 1047, 0.99, 1),
#  (320, 42, 699, 0.99, 1),
#  (321, 42, 580, 0.99, 1),
#  (322, 42, 897, 0.99, 1),
#  (323, 42, 153, 0.99, 1),
#  (324, 43, 918, 0.99, 1),
#  (325, 43, 2342, 0.99, 1),
#  (326, 43, 1162, 0.99, 1),
#  (327, 43, 1654, 0.99, 1),
#  (328, 43, 1768, 0.99, 1),
#  (329, 43, 2641, 0.99, 1),
#  (330, 43, 1997, 0.99, 1),
#  (331, 44, 3052, 0.99, 1),
#  (332, 44, 3053, 0.99, 1),
#  (333, 44, 3054, 0.99, 1),
#  (334, 44, 3055, 0.99, 1),
#  (335, 44, 3056, 0.99, 1),
#  (336, 44, 3057, 0.99, 1),
#  (337, 44, 3058, 0.99, 1),
#  (338, 44, 3059, 0.99, 1),
#  (339, 44, 3060, 0.99, 1),
#  (340, 44, 3061, 0.99, 1),
#  (341, 44, 3062, 0.99, 1),
#  (342, 44, 3063, 0.99, 1),
#  (343, 45, 1890, 0.99, 1),
#  (344, 45, 1787, 0.99, 1),
#  (345, 45, 2731, 0.99, 1),
#  (346, 45, 2649, 0.99, 1),
#  (347, 45, 102, 0.99, 1),
#  (348, 45, 158, 0.99, 1),
#  (349, 45, 1976, 0.99, 1),
#  (350, 45, 1837, 0.99, 1),
#  (351, 46, 2639, 0.99, 1),
#  (352, 46, 2640, 0.99, 1),
#  (353, 46, 2641, 0.99, 1),
#  (354, 46, 2642, 0.99, 1),
#  (355, 46, 2643, 0.99, 1),
#  (356, 46, 2644, 0.99, 1),
#  (357, 46, 2645, 0.99, 1),
#  (358, 46, 2646, 0.99, 1),
#  (359, 46, 2647, 0.99, 1),
#  (360, 46, 2648, 0.99, 1),
#  (361, 46, 2649, 0.99, 1),
#  (362, 47, 3396, 0.99, 1),
#  (363, 47, 2518, 0.99, 1),
#  (364, 47, 2095, 0.99, 1),
#  (365, 47, 449, 0.99, 1),
#  (366, 47, 478, 0.99, 1),
#  (367, 47, 8, 0.99, 1),
#  (368, 48, 2210, 0.99, 1),
#  (369, 48, 427, 0.99, 1),
#  (370, 48, 1167, 0.99, 1),
#  (371, 48, 58, 0.99, 1),
#  (372, 49, 2561, 0.99, 1),
#  (373, 49, 1877, 0.99, 1),
#  (374, 49, 146, 0.99, 1),
#  (375, 49, 1162, 0.99, 1),
#  (376, 49, 146, 0.99, 1),
#  (377, 50, 1905, 0.99, 1),
#  (378, 50, 2155, 0.99, 1),
#  (379, 50, 3388, 0.99, 1),
#  (380, 50, 2455, 0.99, 1),
#  (381, 50, 1794, 0.99, 1),
#  (382, 50, 1511, 0.99, 1),
#  (383, 50, 3455, 0.99, 1),
#  (384, 51, 2265, 0.99, 1),
#  (385, 51, 2171, 0.99, 1),
#  (386, 51, 692, 0.99, 1),
#  (387, 51, 3046, 0.99, 1),
#  (388, 51, 1184, 0.99, 1),
#  (389, 51, 126, 0.99, 1),
#  (390, 51, 475, 0.99, 1),
#  (391, 51, 34, 0.99, 1),
#  (392, 52, 2664, 0.99, 1),
#  (393, 52, 2665, 0.99, 1),
#  (394, 52, 2666, 0.99, 1),
#  (395, 52, 2667, 0.99, 1),
#  (396, 52, 2668, 0.99, 1),
#  (397, 52, 2669, 0.99, 1),
#  (398, 52, 2670, 0.99, 1),
#  (399, 52, 2671, 0.99, 1),
#  (400, 52, 2672, 0.99, 1),
#  (401, 52, 2673, 0.99, 1),
#  (402, 52, 2674, 0.99, 1),
#  (403, 52, 2675, 0.99, 1),
#  (404, 53, 1551, 0.99, 1),
#  (405, 53, 207, 0.99, 1),
#  (406, 53, 1846, 0.99, 1),
#  (407, 54, 1773, 0.99, 1),
#  (408, 54, 1774, 0.99, 1),
#  (409, 54, 1775, 0.99, 1),
#  (410, 54, 1776, 0.99, 1),
#  (411, 54, 1777, 0.99, 1),
#  (412, 54, 1778, 0.99, 1),
#  (413, 54, 1779, 0.99, 1),
#  (414, 54, 1780, 0.99, 1),
#  (415, 54, 1781, 0.99, 1),
#  (416, 54, 1782, 0.99, 1),
#  (417, 54, 1783, 0.99, 1),
#  (418, 54, 1784, 0.99, 1),
#  (419, 54, 1785, 0.99, 1),
#  (420, 54, 1786, 0.99, 1),
#  (421, 54, 1787, 0.99, 1),
#  (422, 54, 1788, 0.99, 1),
#  (423, 54, 1789, 0.99, 1),
#  (424, 54, 1790, 0.99, 1),
#  (425, 55, 1552, 0.99, 1),
#  (426, 55, 2672, 0.99, 1),
#  (427, 55, 2006, 0.99, 1),
#  (428, 55, 2453, 0.99, 1),
#  (429, 55, 548, 0.99, 1),
#  (430, 55, 349, 0.99, 1),
#  (431, 55, 2552, 0.99, 1),
#  (432, 55, 2675, 0.99, 1),
#  (433, 55, 155, 0.99, 1),
#  (434, 55, 481, 0.99, 1),
#  (435, 56, 2254, 0.99, 1),
#  (436, 56, 2255, 0.99, 1),
#  (437, 56, 2256, 0.99, 1),
#  (438, 56, 2257, 0.99, 1),
#  (439, 56, 2258, 0.99, 1),
#  (440, 56, 2259, 0.99, 1),
#  (441, 56, 2260, 0.99, 1),
#  (442, 56, 2261, 0.99, 1),
#  (443, 56, 2262, 0.99, 1),
#  (444, 56, 2263, 0.99, 1),
#  (445, 56, 2264, 0.99, 1),
#  (446, 56, 2265, 0.99, 1),
#  (447, 56, 2266, 0.99, 1),
#  (448, 56, 2267, 0.99, 1),
#  (449, 56, 2268, 0.99, 1),
#  (450, 56, 2269, 0.99, 1),
#  (451, 56, 2270, 0.99, 1),
#  (452, 57, 2948, 0.99, 1),
#  (453, 58, 1029, 0.99, 1),
#  (454, 58, 2644, 0.99, 1),
#  (455, 58, 2395, 0.99, 1),
#  (456, 58, 2669, 0.99, 1),
#  (457, 58, 2630, 0.99, 1),
#  (458, 58, 1745, 0.99, 1),
#  (459, 59, 449, 0.99, 1),
#  (460, 59, 3491, 0.99, 1),
#  (461, 59, 1053, 0.99, 1),
#  (462, 59, 2640, 0.99, 1),
#  (463, 59, 2563, 0.99, 1),
#  (464, 59, 2731, 0.99, 1),
#  (465, 59, 1123, 0.99, 1),
#  (466, 59, 198, 0.99, 1),
#  (467, 59, 3336, 0.99, 1),
#  (468, 59, 1463, 0.99, 1),
#  (469, 59, 3390, 0.99, 1),
#  (470, 60, 479, 0.99, 1),
#  (471, 60, 1875, 0.99, 1),
#  (472, 60, 544, 0.99, 1),
#  (473, 60, 1030, 0.99, 1),
#  (474, 60, 2416, 0.99, 1),
#  (475, 60, 1167, 0.99, 1),
#  (476, 60, 1826, 0.99, 1),
#  (477, 60, 46, 0.99, 1),
#  (478, 61, 2609, 0.99, 1),
#  (479, 61, 2610, 0.99, 1),
#  (480, 61, 2611, 0.99, 1),
#  (481, 61, 2612, 0.99, 1),
#  (482, 61, 2613, 0.99, 1),
#  (483, 61, 2614, 0.99, 1),
#  (484, 61, 2615, 0.99, 1),
#  (485, 61, 2616, 0.99, 1),
#  (486, 61, 2617, 0.99, 1),
#  (487, 61, 2618, 0.99, 1),
#  (488, 61, 2619, 0.99, 1),
#  (489, 61, 2620, 0.99, 1),
#  (490, 62, 2989, 0.99, 1),
#  (491, 62, 97, 0.99, 1),
#  (492, 62, 2680, 0.99, 1),
#  (493, 63, 444, 0.99, 1),
#  (494, 63, 3470, 0.99, 1),
#  (495, 63, 3376, 0.99, 1),
#  (496, 63, 1994, 0.99, 1),
#  (497, 63, 6, 0.99, 1),
#  (498, 63, 8, 0.99, 1),
#  (499, 64, 38, 0.99, 1),
#  (500, 64, 39, 0.99, 1),
#  (501, 64, 40, 0.99, 1),
#  (502, 64, 41, 0.99, 1),
#  (503, 64, 42, 0.99, 1),
#  (504, 64, 43, 0.99, 1),
#  (505, 64, 44, 0.99, 1),
#  (506, 64, 45, 0.99, 1),
#  (507, 64, 46, 0.99, 1),
#  (508, 64, 47, 0.99, 1),
#  (509, 64, 48, 0.99, 1),
#  (510, 64, 49, 0.99, 1),
#  (511, 64, 50, 0.99, 1),
#  (512, 65, 1139, 0.99, 1),
#  (513, 65, 539, 0.99, 1),
#  (514, 66, 1435, 0.99, 1),
#  (515, 66, 1761, 0.99, 1),
#  (516, 66, 3377, 0.99, 1),
#  (517, 66, 1785, 0.99, 1),
#  (518, 66, 442, 0.99, 1),
#  (519, 66, 1951, 0.99, 1),
#  (520, 66, 2334, 0.99, 1),
#  (521, 67, 2401, 0.99, 1),
#  (522, 67, 2287, 0.99, 1),
#  (523, 67, 84, 0.99, 1),
#  (524, 67, 3099, 0.99, 1),
#  (525, 67, 3468, 0.99, 1),
#  (526, 67, 2413, 0.99, 1),
#  (527, 67, 2164, 0.99, 1),
#  (528, 67, 3478, 0.99, 1),
#  (529, 67, 787, 0.99, 1),
#  (530, 67, 9, 0.99, 1),
#  (531, 67, 861, 0.99, 1),
#  (532, 68, 2575, 0.99, 1),
#  (533, 68, 1669, 0.99, 1),
#  (534, 68, 2265, 0.99, 1),
#  (535, 68, 61, 0.99, 1),
#  (536, 68, 751, 0.99, 1),
#  (537, 68, 3353, 0.99, 1),
#  (538, 68, 2008, 0.99, 1),
#  (539, 68, 1903, 0.99, 1),
#  (540, 68, 910, 0.99, 1),
#  (541, 68, 2236, 0.99, 1),
#  (542, 68, 1990, 0.99, 1),
#  (543, 69, 85, 0.99, 1),
#  (544, 69, 86, 0.99, 1),
#  (545, 69, 87, 0.99, 1),
#  (546, 69, 88, 0.99, 1),
#  (547, 69, 89, 0.99, 1),
#  (548, 69, 90, 0.99, 1),
#  (549, 69, 91, 0.99, 1),
#  (550, 69, 92, 0.99, 1),
#  (551, 69, 93, 0.99, 1),
#  (552, 69, 94, 0.99, 1),
#  (553, 69, 95, 0.99, 1),
#  (554, 69, 96, 0.99, 1),
#  (555, 69, 97, 0.99, 1),
#  (556, 69, 98, 0.99, 1),
#  (557, 70, 2307, 0.99, 1),
#  (558, 71, 2254, 0.99, 1),
#  (559, 71, 2255, 0.99, 1),
#  (560, 71, 2256, 0.99, 1),
#  (561, 71, 2257, 0.99, 1),
#  (562, 71, 2258, 0.99, 1),
#  (563, 71, 2259, 0.99, 1),
#  (564, 71, 2260, 0.99, 1),
#  (565, 71, 2261, 0.99, 1),
#  (566, 71, 2262, 0.99, 1),
#  (567, 71, 2263, 0.99, 1),
#  (568, 71, 2264, 0.99, 1),
#  (569, 71, 2265, 0.99, 1),
#  (570, 71, 2266, 0.99, 1),
#  (571, 71, 2267, 0.99, 1),
#  (572, 71, 2268, 0.99, 1),
#  (573, 71, 2269, 0.99, 1),
#  (574, 71, 2270, 0.99, 1),
#  (575, 72, 30, 0.99, 1),
#  (576, 72, 2564, 0.99, 1),
#  (577, 72, 1658, 0.99, 1),
#  (578, 73, 2391, 0.99, 1),
#  (579, 73, 2392, 0.99, 1),
#  (580, 73, 2393, 0.99, 1),
#  (581, 73, 2394, 0.99, 1),
#  (582, 73, 2395, 0.99, 1),
#  (583, 73, 2396, 0.99, 1),
#  (584, 73, 2397, 0.99, 1),
#  (585, 73, 2398, 0.99, 1),
#  (586, 73, 2399, 0.99, 1),
#  (587, 73, 2400, 0.99, 1),
#  (588, 73, 2401, 0.99, 1),
#  (589, 73, 2402, 0.99, 1),
#  (590, 73, 2403, 0.99, 1),
#  (591, 73, 2404, 0.99, 1),
#  (592, 73, 2405, 0.99, 1),
#  (593, 74, 1743, 0.99, 1),
#  (594, 74, 3081, 0.99, 1),
#  (595, 75, 22, 0.99, 1),
#  (596, 75, 1488, 0.99, 1),
#  (597, 75, 1977, 0.99, 1),
#  (598, 75, 1233, 0.99, 1),
#  (599, 76, 1020, 0.99, 1),
#  (600, 76, 1021, 0.99, 1),
#  (601, 76, 1022, 0.99, 1),
#  (602, 76, 1023, 0.99, 1),
#  (603, 76, 1024, 0.99, 1),
#  (604, 76, 1025, 0.99, 1),
#  (605, 76, 1026, 0.99, 1),
#  (606, 76, 1027, 0.99, 1),
#  (607, 76, 1028, 0.99, 1),
#  (608, 76, 1029, 0.99, 1),
#  (609, 76, 1030, 0.99, 1),
#  (610, 76, 1031, 0.99, 1),
#  (611, 76, 1032, 0.99, 1),
#  (612, 77, 15, 0.99, 1),
#  (613, 77, 17, 0.99, 1),
#  (614, 77, 18, 0.99, 1),
#  (615, 77, 19, 0.99, 1),
#  (616, 77, 20, 0.99, 1),
#  (617, 77, 22, 0.99, 1),
#  (618, 78, 2592, 0.99, 1),
#  (619, 78, 1052, 0.99, 1),
#  (620, 78, 33, 0.99, 1),
#  (621, 78, 3336, 0.99, 1),
#  (622, 78, 1215, 0.99, 1),
#  (623, 78, 3370, 0.99, 1),
#  (624, 78, 2553, 0.99, 1),
#  (625, 78, 1126, 0.99, 1),
#  (626, 78, 3006, 0.99, 1),
#  (627, 79, 1902, 0.99, 1),
#  (628, 79, 1903, 0.99, 1),
#  (629, 79, 1904, 0.99, 1),
#  (630, 79, 1905, 0.99, 1),
#  (631, 79, 1906, 0.99, 1),
#  (632, 79, 1907, 0.99, 1),
#  (633, 79, 1908, 0.99, 1),
#  (634, 79, 1909, 0.99, 1),
#  (635, 79, 1910, 0.99, 1),
#  (636, 79, 1911, 0.99, 1),
#  (637, 79, 1912, 0.99, 1),
#  (638, 79, 1913, 0.99, 1),
#  (639, 79, 1914, 0.99, 1),
#  (640, 79, 1915, 0.99, 1),
#  (641, 80, 3400, 0.99, 1),
#  (642, 81, 1314, 0.99, 1),
#  (643, 81, 839, 0.99, 1),
#  (644, 81, 545, 0.99, 1),
#  (645, 81, 2554, 0.99, 1),
#  (646, 81, 904, 0.99, 1),
#  (647, 81, 3079, 0.99, 1),
#  (648, 82, 3291, 0.99, 1),
#  (649, 82, 1348, 0.99, 1),
#  (650, 82, 2417, 0.99, 1),
#  (651, 82, 2120, 0.99, 1),
#  (652, 82, 1332, 0.99, 1),
#  (653, 82, 2704, 0.99, 1),
#  (654, 82, 54, 0.99, 1),
#  (655, 83, 1163, 0.99, 1),
#  (656, 83, 1996, 0.99, 1),
#  (657, 83, 2750, 0.99, 1),
#  (658, 83, 2998, 0.99, 1),
#  (659, 84, 3455, 0.99, 1),
#  (660, 84, 3456, 0.99, 1),
#  (661, 84, 3457, 0.99, 1),
#  (662, 84, 3458, 0.99, 1),
#  (663, 84, 3459, 0.99, 1),
#  (664, 84, 3460, 0.99, 1),
#  (665, 84, 3461, 0.99, 1),
#  (666, 84, 3462, 0.99, 1),
#  (667, 84, 3463, 0.99, 1),
#  (668, 84, 3464, 0.99, 1),
#  (669, 84, 3465, 0.99, 1),
#  (670, 84, 3466, 0.99, 1),
#  (671, 85, 2555, 0.99, 1),
#  (672, 85, 1298, 0.99, 1),
#  (673, 85, 2740, 0.99, 1),
#  (674, 85, 2561, 0.99, 1),
#  (675, 85, 1972, 0.99, 1),
#  (676, 86, 2291, 0.99, 1),
#  (677, 87, 1600, 0.99, 1),
#  (678, 87, 2226, 0.99, 1),
#  (679, 87, 1503, 0.99, 1),
#  (680, 87, 3292, 0.99, 1),
#  (681, 87, 2593, 0.99, 1),
#  (682, 87, 1129, 0.99, 1),
#  (683, 87, 3349, 0.99, 1),
#  (684, 87, 3439, 0.99, 1),
#  (685, 88, 2679, 0.99, 1),
#  (686, 88, 2698, 0.99, 1),
#  (687, 88, 2386, 0.99, 1),
#  (688, 88, 1995, 0.99, 1),
#  (689, 88, 2597, 0.99, 1),
#  (690, 89, 1784, 0.99, 1),
#  (691, 89, 1900, 0.99, 1),
#  (692, 90, 2554, 0.99, 1),
#  (693, 90, 2555, 0.99, 1),
#  (694, 90, 2556, 0.99, 1),
#  (695, 90, 2557, 0.99, 1),
#  (696, 90, 2558, 0.99, 1),
#  (697, 90, 2559, 0.99, 1),
#  (698, 90, 2560, 0.99, 1),
#  (699, 90, 2561, 0.99, 1),
#  (700, 90, 2562, 0.99, 1),
#  (701, 90, 2563, 0.99, 1),
#  (702, 90, 2564, 0.99, 1),
#  (703, 91, 1209, 0.99, 1),
#  (704, 91, 130, 0.99, 1),
#  (705, 91, 94, 0.99, 1),
#  (706, 91, 2367, 0.99, 1),
#  (707, 91, 2599, 0.99, 1),
#  (708, 91, 1948, 0.99, 1),
#  (709, 91, 1488, 0.99, 1),
#  (710, 91, 2654, 0.99, 1),
#  (711, 91, 3424, 0.99, 1),
#  (712, 91, 481, 0.99, 1),
#  (713, 91, 1817, 0.99, 1),
#  (714, 92, 1414, 0.99, 1),
#  (715, 92, 1415, 0.99, 1),
#  (716, 92, 1416, 0.99, 1),
#  (717, 92, 1417, 0.99, 1),
#  (718, 92, 1418, 0.99, 1),
#  (719, 92, 1419, 0.99, 1),
#  (720, 92, 1420, 0.99, 1),
#  (721, 92, 1421, 0.99, 1),
#  (722, 92, 1422, 0.99, 1),
#  (723, 92, 1423, 0.99, 1),
#  (724, 92, 1424, 0.99, 1),
#  (725, 92, 1425, 0.99, 1),
#  (726, 92, 1426, 0.99, 1),
#  (727, 92, 1427, 0.99, 1),
#  (728, 92, 1428, 0.99, 1),
#  (729, 92, 1429, 0.99, 1),
#  (730, 92, 1430, 0.99, 1),
#  (731, 92, 1431, 0.99, 1),
#  (732, 92, 1432, 0.99, 1),
#  (733, 92, 1433, 0.99, 1),
#  (734, 93, 1490, 0.99, 1),
#  (735, 93, 778, 0.99, 1),
#  (736, 93, 1787, 0.99, 1),
#  (737, 93, 1121, 0.99, 1),
#  (738, 93, 2639, 0.99, 1),
#  (739, 93, 2261, 0.99, 1),
#  (740, 93, 20, 0.99, 1),
#  (741, 93, 3041, 0.99, 1),
#  (742, 93, 1798, 0.99, 1),
#  (743, 93, 1023, 0.99, 1),
#  (744, 94, 50, 0.99, 1),
#  (745, 94, 1173, 0.99, 1),
#  (746, 94, 2657, 0.99, 1),
#  (747, 94, 1064, 0.99, 1),
#  (748, 94, 3359, 0.99, 1),
#  (749, 94, 1677, 0.99, 1),
#  (750, 94, 1351, 0.99, 1),
#  (751, 94, 2595, 0.99, 1),
#  (752, 95, 3299, 0.99, 1),
#  (753, 95, 2550, 0.99, 1),
#  (754, 95, 1278, 0.99, 1),
#  (755, 95, 473, 0.99, 1),
#  (756, 95, 1001, 0.99, 1),
#  (757, 95, 110, 0.99, 1),
#  (758, 95, 54, 0.99, 1),
#  (759, 95, 27, 0.99, 1),
#  (760, 95, 681, 0.99, 1),
#  (761, 95, 3078, 0.99, 1),
#  (762, 95, 2339, 0.99, 1),
#  (763, 96, 1129, 0.99, 1),
#  (764, 96, 2227, 0.99, 1),
#  (765, 96, 1000, 0.99, 1),
#  (766, 96, 3438, 0.99, 1),
#  (767, 96, 2189, 0.99, 1),
#  (768, 96, 453, 0.99, 1),
#  (769, 97, 1784, 0.99, 1),
#  (770, 97, 3336, 0.99, 1),
#  (771, 97, 3104, 0.99, 1),
#  (772, 97, 16, 0.99, 1),
#  (773, 97, 2544, 0.99, 1),
#  (774, 97, 454, 0.99, 1),
#  (775, 98, 1995, 0.99, 1),
#  (776, 98, 2624, 0.99, 1),
#  (777, 98, 690, 0.99, 1),
#  (778, 98, 419, 0.99, 1),
#  (779, 98, 1852, 0.99, 1),
#  (780, 98, 609, 0.99, 1),
#  (781, 98, 2426, 0.99, 1),
#  (782, 98, 1904, 0.99, 1),
#  (783, 98, 2645, 0.99, 1),
#  (784, 98, 2255, 0.99, 1),
#  (785, 99, 2591, 0.99, 1),
#  (786, 99, 2592, 0.99, 1),
#  (787, 99, 2593, 0.99, 1),
#  (788, 99, 2594, 0.99, 1),
#  (789, 99, 2595, 0.99, 1),
#  (790, 99, 2596, 0.99, 1),
#  (791, 99, 2597, 0.99, 1),
#  (792, 99, 2598, 0.99, 1),
#  (793, 99, 2599, 0.99, 1),
#  (794, 99, 2600, 0.99, 1),
#  (795, 99, 2601, 0.99, 1),
#  (796, 99, 2602, 0.99, 1),
#  (797, 99, 2603, 0.99, 1),
#  (798, 99, 2604, 0.99, 1),
#  (799, 99, 2605, 0.99, 1),
#  (800, 99, 2606, 0.99, 1),
#  (801, 99, 2607, 0.99, 1),
#  (802, 99, 2608, 0.99, 1),
#  (803, 100, 996, 0.99, 1),
#  (804, 100, 2560, 0.99, 1),
#  (805, 100, 2006, 0.99, 1),
#  (806, 100, 2648, 0.99, 1),
#  (807, 100, 1181, 0.99, 1),
#  (808, 100, 1493, 0.99, 1),
#  (809, 101, 3356, 0.99, 1),
#  (810, 101, 83, 0.99, 1),
#  (811, 101, 2519, 0.99, 1),
#  (812, 101, 2269, 0.99, 1),
#  (813, 102, 3472, 0.99, 1),
#  (814, 102, 1486, 0.99, 1),
#  (815, 102, 1372, 0.99, 1),
#  (816, 102, 33, 0.99, 1),
#  (817, 102, 1992, 0.99, 1),
#  (818, 102, 421, 0.99, 1),
#  (819, 102, 1469, 0.99, 1),
#  (820, 102, 1197, 0.99, 1),
#  (821, 102, 1218, 0.99, 1),
#  (822, 102, 2549, 0.99, 1),
#  (823, 103, 2234, 0.99, 1),
#  (824, 103, 2007, 0.99, 1),
#  (825, 103, 2275, 0.99, 1),
#  (826, 103, 2419, 0.99, 1),
#  (827, 103, 1029, 0.99, 1),
#  (828, 103, 3336, 0.99, 1),
#  (829, 104, 3097, 0.99, 1),
#  (830, 104, 1508, 0.99, 1),
#  (831, 105, 751, 0.99, 1),
#  (832, 105, 3355, 0.99, 1),
#  (833, 105, 2385, 0.99, 1),
#  (834, 105, 2187, 0.99, 1),
#  (835, 105, 2748, 0.99, 1),
#  (836, 105, 1793, 0.99, 1),
#  (837, 105, 2381, 0.99, 1),
#  (838, 105, 1387, 0.99, 1),
#  (839, 106, 2, 0.99, 1),
#  (840, 106, 1485, 0.99, 1),
#  (841, 106, 2186, 0.99, 1),
#  (842, 106, 1592, 0.99, 1),
#  (843, 106, 3476, 0.99, 1),
#  (844, 106, 2445, 0.99, 1),
#  (845, 106, 1814, 0.99, 1),
#  (846, 106, 488, 0.99, 1),
#  (847, 107, 1179, 0.99, 1),
#  (848, 107, 2011, 0.99, 1),
#  (849, 107, 700, 0.99, 1),
#  (850, 107, 1984, 0.99, 1),
#  (851, 107, 1819, 0.99, 1),
#  (852, 107, 1799, 0.99, 1),
#  (853, 107, 24, 0.99, 1),
#  (854, 107, 3288, 0.99, 1),
#  (855, 107, 1, 0.99, 1),
#  (856, 107, 2419, 0.99, 1),
#  (857, 107, 1132, 0.99, 1),
#  (858, 108, 102, 0.99, 1),
#  (859, 108, 58, 0.99, 1),
#  (860, 108, 158, 0.99, 1),
#  (861, 108, 1214, 0.99, 1),
#  (862, 108, 2737, 0.99, 1),
#  (863, 109, 486, 0.99, 1),
#  (864, 109, 1055, 0.99, 1),
#  (865, 109, 1796, 0.99, 1),
#  (866, 109, 1195, 0.99, 1),
#  (867, 109, 2445, 0.99, 1),
#  (868, 109, 709, 0.99, 1),
#  (869, 109, 681, 0.99, 1),
#  (870, 109, 3293, 0.99, 1),
#  (871, 109, 425, 0.99, 1),
#  (872, 109, 340, 0.99, 1),
#  (873, 109, 2381, 0.99, 1),
#  (874, 110, 444, 0.99, 1),
#  (875, 110, 2596, 0.99, 1),
#  (876, 110, 81, 0.99, 1),
#  (877, 110, 3378, 0.99, 1),
#  (878, 110, 3105, 0.99, 1),
#  (879, 110, 2234, 0.99, 1),
#  (880, 111, 3484, 0.99, 1),
#  (881, 111, 2429, 0.99, 1),
#  (882, 111, 597, 0.99, 1),
#  (883, 111, 1139, 0.99, 1),
#  (884, 111, 48, 0.99, 1),
#  (885, 112, 1479, 0.99, 1),
#  (886, 112, 1480, 0.99, 1),
#  (887, 112, 1481, 0.99, 1),
#  (888, 112, 1482, 0.99, 1),
#  (889, 112, 1483, 0.99, 1),
#  (890, 112, 1484, 0.99, 1),
#  (891, 112, 1485, 0.99, 1),
#  (892, 112, 1486, 0.99, 1),
#  (893, 112, 1487, 0.99, 1),
#  (894, 112, 1488, 0.99, 1),
#  (895, 112, 1489, 0.99, 1),
#  (896, 112, 1490, 0.99, 1),
#  (897, 112, 1491, 0.99, 1),
#  (898, 112, 1492, 0.99, 1),
#  (899, 112, 1493, 0.99, 1),
#  (900, 112, 1494, 0.99, 1),
#  (901, 112, 1495, 0.99, 1),
#  (902, 113, 2762, 0.99, 1),
#  (903, 113, 2383, 0.99, 1),
#  (904, 113, 2662, 0.99, 1),
#  (905, 113, 2693, 0.99, 1),
#  (906, 113, 1657, 0.99, 1),
#  (907, 113, 577, 0.99, 1),
#  (908, 113, 1034, 0.99, 1),
#  (909, 113, 134, 0.99, 1),
#  (910, 113, 1473, 0.99, 1),
#  (911, 113, 3087, 0.99, 1),
#  (912, 114, 1479, 0.99, 1),
#  (913, 114, 1480, 0.99, 1),
#  (914, 114, 1481, 0.99, 1),
#  (915, 114, 1482, 0.99, 1),
#  (916, 114, 1483, 0.99, 1),
#  (917, 114, 1484, 0.99, 1),
#  (918, 114, 1485, 0.99, 1),
#  (919, 114, 1486, 0.99, 1),
#  (920, 114, 1487, 0.99, 1),
#  (921, 114, 1488, 0.99, 1),
#  (922, 114, 1489, 0.99, 1),
#  (923, 114, 1490, 0.99, 1),
#  (924, 114, 1491, 0.99, 1),
#  (925, 114, 1492, 0.99, 1),
#  (926, 114, 1493, 0.99, 1),
#  (927, 114, 1494, 0.99, 1),
#  (928, 114, 1495, 0.99, 1),
#  (929, 115, 298, 0.99, 1),
#  (930, 115, 2269, 0.99, 1),
#  (931, 115, 2610, 0.99, 1),
#  (932, 115, 1188, 0.99, 1),
#  (933, 115, 3370, 0.99, 1),
#  (934, 115, 2990, 0.99, 1),
#  (935, 115, 2684, 0.99, 1),
#  (936, 115, 1224, 0.99, 1),
#  (937, 115, 84, 0.99, 1),
#  (938, 116, 571, 0.99, 1),
#  (939, 116, 2739, 0.99, 1),
#  (940, 116, 1568, 0.99, 1),
#  (941, 116, 2975, 0.99, 1),
#  (942, 116, 1887, 0.99, 1),
#  (943, 116, 3092, 0.99, 1),
#  (944, 116, 35, 0.99, 1),
#  (945, 116, 66, 0.99, 1),
#  (946, 116, 1180, 0.99, 1),
#  (947, 116, 21, 0.99, 1),
#  (948, 116, 2254, 0.99, 1),
#  (949, 117, 4, 0.99, 1),
#  (950, 117, 3316, 0.99, 1),
#  (951, 117, 2558, 0.99, 1),
#  (952, 117, 2591, 0.99, 1),
#  (953, 117, 1880, 0.99, 1),
#  (954, 117, 831, 0.99, 1),
#  (955, 117, 1482, 0.99, 1),
#  (956, 117, 2174, 0.99, 1),
#  (957, 117, 3305, 0.99, 1),
#  (958, 117, 3365, 0.99, 1),
#  (959, 117, 614, 0.99, 1),
#  (960, 118, 3111, 0.99, 1),
#  (961, 119, 1556, 0.99, 1),
#  (962, 119, 2508, 0.99, 1),
#  (963, 120, 17, 0.99, 1),
#  (964, 120, 1126, 0.99, 1),
#  (965, 120, 2749, 0.99, 1),
#  (966, 120, 2596, 0.99, 1),
#  (967, 120, 2738, 0.99, 1),
#  (968, 120, 2350, 0.99, 1),
#  (969, 121, 2656, 0.99, 1),
#  (970, 121, 2549, 0.99, 1),
#  (971, 121, 1829, 0.99, 1),
#  (972, 121, 44, 0.99, 1),
#  (973, 121, 40, 0.99, 1),
#  (974, 121, 2674, 0.99, 1),
#  (975, 121, 3452, 0.99, 1),
#  (976, 121, 344, 0.99, 1),
#  (977, 121, 32, 0.99, 1),
#  (978, 122, 2014, 0.99, 1),
#  (979, 122, 28, 0.99, 1),
#  (980, 122, 42, 0.99, 1),
#  (981, 122, 839, 0.99, 1),
#  (982, 122, 1195, 0.99, 1),
#  (983, 123, 2003, 0.99, 1),
#  (984, 123, 2004, 0.99, 1),
#  (985, 123, 2005, 0.99, 1),
#  (986, 123, 2006, 0.99, 1),
#  (987, 123, 2007, 0.99, 1),
#  (988, 123, 2008, 0.99, 1),
#  (989, 123, 2009, 0.99, 1),
#  (990, 123, 2010, 0.99, 1),
#  (991, 123, 2011, 0.99, 1),
#  (992, 123, 2012, 0.99, 1),
#  (993, 123, 2013, 0.99, 1),
#  (994, 123, 2014, 0.99, 1),
#  (995, 124, 3100, 0.99, 1),
#  (996, 124, 3323, 0.99, 1),
#  (997, 124, 2328, 0.99, 1),
#  (998, 124, 470, 0.99, 1),
#  (999, 124, 1017, 0.99, 1),
#  (1000, 124, 1816, 0.99, 1),
#  ...]

# %%
# %%sql
#
# -- finding nummber of tracks per album
#
# WITH tracks_each_album as(
#     SELECT
#         DISTINCT a.album_id ,
#         COUNT(t.track_id) number_of_tracks
#     from track t
#     inner join album a on
#     a.album_id = t.album_id
#     group by 1
# ),
#
# -- finding number of tracks per invoice
#
# tracks_each_invoice as(
#     SELECT
#         il.invoice_id,
#         t.album_id,
#         COUNT(il.track_id) number_of_tracks
#     from track t
#     inner join invoice_line il on
#     il.track_id = t.track_id
#     group by 1,2
# )
#
# SELECT
#     invoice_type,
#     COUNT(DISTINCT il.invoice_id) number_of_invoices,
#     ROUND(CAST(COUNT(DISTINCT it.invoice_id) as FLOAT)/(SELECT COUNT(*)  FROM invoice) * 100, 2) || "%" percentage
# FROM(
#     SELECT
#         il.invoice_id, MIN(il.track_id),
#         CASE
#             WHEN tea.number_of_tracks = tei.number_of_tracks THEN "Album"
#             ELSE "Individual tracks"
#         END as invoice_type
#     FROM invoice_line il
#     inner join tracks_each_invoice tei on il.invoice_id = tei.invoice_id
#     inner join tracks_each_album tea on tei.album_id = tea.album_id
#     GROUP BY 1
# ) it
# inner join invoice_line il on il.invoice_id = it.invoice_id
# group by 1
# Out:
# Done.
# [('Album', 117, '19.06%'), ('Individual tracks', 497, '80.94%')]

# %% [markdown]
# It appears that customers are likely to purchase individual tracks 4 times more than an album. Thus, the strategy to purchase only the most popular tracks would work fairly well with the preference of customers for individual tracks.
